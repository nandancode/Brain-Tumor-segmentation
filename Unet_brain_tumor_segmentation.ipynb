# %%
import os
# os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose, concatenate, Input
from tensorflow.keras.models import Model
# Out:
# 2023-08-15 16:27:09.506017: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def build_unet(input_shape):
    inputs = Input(input_shape)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    
    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(up6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    
    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(up7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(up8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    
    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(up9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)
        
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv9)
    
    model = Model(inputs, outputs, name="UNET")
    return model

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = build_unet(input_shape)
    model.summary()
# Out:
# 2023-08-15 16:27:13.326355: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-08-15 16:27:13.327383: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-08-15 16:27:13.472135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-08-15 16:27:13.472168: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-15 16:27:13.473867: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-08-15 16:27:13.473898: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-08-15 16:27:13.475500: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-08-15 16:27:13.475735: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-08-15 16:27:13.477394: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-08-15 16:27:13.478321: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-08-15 16:27:13.482005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-08-15 16:27:13.485884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-08-15 16:27:13.486480: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-15 16:27:13.489802: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-08-15 16:27:13.491901: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-08-15 16:27:13.491923: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-15 16:27:13.491940: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-08-15 16:27:13.491954: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-08-15 16:27:13.491967: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-08-15 16:27:13.491980: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-08-15 16:27:13.491994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-08-15 16:27:13.492007: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-08-15 16:27:13.492020: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-08-15 16:27:13.495773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-08-15 16:27:13.495810: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-15 16:27:14.069501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-08-15 16:27:14.069543: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2023-08-15 16:27:14.069551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2023-08-15 16:27:14.075360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30130 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:0a:00.0, compute capability: 7.0)
# Model: "UNET"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  2097664     batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 128 512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 128 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  65          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K

# %%
""" Global parameters """
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
H = 256
W = 256
smooth = 1.

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def load_dataset(path, split=0.2):
    images = sorted(glob(os.path.join(path, "images", "*.png")))
    masks = sorted(glob(os.path.join(path, "masks", "*.png")))

    split_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (h, w)
    x = cv2.resize(x, (W, H))   ## (h, w)
    x = x / 255.0               ## (h, w)
    x = x.astype(np.float32)    ## (h, w)
    x = np.expand_dims(x, axis=-1)## (h, w, 1)
    return x

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
augmentation_args = dict(
    rotation_range=0.2,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    fill_mode='nearest'
)

image_datagen = ImageDataGenerator(**augmentation_args)
mask_datagen = ImageDataGenerator(**augmentation_args)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def read_and_augment_image(image_path):
    image = read_image(image_path)
    augmented_image = image_datagen.random_transform(image)
    return augmented_image

def read_and_augment_mask(mask_path):
    mask = read_mask(mask_path)
    augmented_mask = mask_datagen.random_transform(mask)
    return augmented_mask

def tf_parse_augmented(x, y):
    def _parse_augmented(x, y):
        x = read_and_augment_image(x)
        y = read_and_augment_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse_augmented, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset_augmented(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse_augmented)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_coef(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  return iou


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def loss(y_true, y_pred):
    return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

# %%
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth = True
# config.log_device_placement = True
# sess = tf.compat.v1.Session(config=config)

# config = tf.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.6  # 0.6 sometimes works better for folks
# keras.backend.tensorflow_backend.set_session(tf.Session(config=config))

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 16
    lr = 1e-4
    num_epochs = 500
    model_path = os.path.join("files", "model.h5")
    csv_path = os.path.join("files", "log.csv")

    """ Dataset """
    dataset_path = "/home/akshatt/nandan/dataset/dataset/archive/"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test : {len(test_x)} - {len(test_y)}")
    
#     train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
#     valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
    
    train_dataset = tf_dataset_augmented(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    """ Model """
    model = build_unet((H, W, 3))
    model.compile(loss=loss, optimizer=Adam(lr), metrics=[dice_coef, iou_coef])

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=False),
    ]

    history = model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 1840 - 1840
# Valid: 612 - 612
# Test : 612 - 612
# 2023-08-15 16:27:32.840979: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-08-15 16:27:32.861231: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2195045000 Hz
# Epoch 1/500
# 2023-08-15 16:27:35.038012: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-08-15 16:27:36.168713: W tensorflow/stream_executor/gpu/asm_compiler.cc:98] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2023-08-15 16:27:36.309186: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 115/115 [==============================] - 37s 275ms/step - loss: -0.0599 - dice_coef: 0.0815 - iou_coef: 0.0456 - val_loss: -0.0228 - val_dice_coef: 0.0354 - val_iou_coef: 0.0138
#
# Epoch 00001: val_loss improved from inf to -0.02279, saving model to files/model.h5
# Epoch 2/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.0974 - dice_coef: 0.1312 - iou_coef: 0.0749 - val_loss: -0.0326 - val_dice_coef: 0.0453 - val_iou_coef: 0.0241
#
# Epoch 00002: val_loss improved from -0.02279 to -0.03265, saving model to files/model.h5
# Epoch 3/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.1133 - dice_coef: 0.1511 - iou_coef: 0.0881 - val_loss: -0.0351 - val_dice_coef: 0.0472 - val_iou_coef: 0.0269
#
# Epoch 00003: val_loss improved from -0.03265 to -0.03512, saving model to files/model.h5
# Epoch 4/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.1383 - dice_coef: 0.1867 - iou_coef: 0.1060 - val_loss: -0.0298 - val_dice_coef: 0.0412 - val_iou_coef: 0.0217
#
# Epoch 00004: val_loss did not improve from -0.03512
# Epoch 5/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.1489 - dice_coef: 0.2004 - iou_coef: 0.1145 - val_loss: -0.0984 - val_dice_coef: 0.1269 - val_iou_coef: 0.0786
#
# Epoch 00005: val_loss improved from -0.03512 to -0.09842, saving model to files/model.h5
# Epoch 6/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.1633 - dice_coef: 0.2196 - iou_coef: 0.1259 - val_loss: -0.2871 - val_dice_coef: 0.3772 - val_iou_coef: 0.2267
#
# Epoch 00006: val_loss improved from -0.09842 to -0.28708, saving model to files/model.h5
# Epoch 7/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.1739 - dice_coef: 0.2381 - iou_coef: 0.1312 - val_loss: -0.2994 - val_dice_coef: 0.3763 - val_iou_coef: 0.2439
#
# Epoch 00007: val_loss improved from -0.28708 to -0.29940, saving model to files/model.h5
# Epoch 8/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.1873 - dice_coef: 0.2555 - iou_coef: 0.1419 - val_loss: -0.3338 - val_dice_coef: 0.4201 - val_iou_coef: 0.2692
#
# Epoch 00008: val_loss improved from -0.29940 to -0.33376, saving model to files/model.h5
# Epoch 9/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.1976 - dice_coef: 0.2723 - iou_coef: 0.1478 - val_loss: -0.3601 - val_dice_coef: 0.4549 - val_iou_coef: 0.2962
#
# Epoch 00009: val_loss improved from -0.33376 to -0.36011, saving model to files/model.h5
# Epoch 10/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2001 - dice_coef: 0.2704 - iou_coef: 0.1533 - val_loss: -0.2922 - val_dice_coef: 0.3708 - val_iou_coef: 0.2357
#
# Epoch 00010: val_loss did not improve from -0.36011
# Epoch 11/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2060 - dice_coef: 0.2808 - iou_coef: 0.1562 - val_loss: -0.3179 - val_dice_coef: 0.4093 - val_iou_coef: 0.2510
#
# Epoch 00011: val_loss did not improve from -0.36011
# Epoch 12/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2142 - dice_coef: 0.2927 - iou_coef: 0.1619 - val_loss: -0.4015 - val_dice_coef: 0.4887 - val_iou_coef: 0.3343
#
# Epoch 00012: val_loss improved from -0.36011 to -0.40149, saving model to files/model.h5
# Epoch 13/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2200 - dice_coef: 0.2976 - iou_coef: 0.1683 - val_loss: -0.3873 - val_dice_coef: 0.4798 - val_iou_coef: 0.3286
#
# Epoch 00013: val_loss did not improve from -0.40149
# Epoch 14/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2225 - dice_coef: 0.2991 - iou_coef: 0.1715 - val_loss: -0.3765 - val_dice_coef: 0.4503 - val_iou_coef: 0.3267
#
# Epoch 00014: val_loss did not improve from -0.40149
# Epoch 15/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2252 - dice_coef: 0.3048 - iou_coef: 0.1721 - val_loss: -0.3661 - val_dice_coef: 0.4430 - val_iou_coef: 0.3062
#
# Epoch 00015: val_loss did not improve from -0.40149
# Epoch 16/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2265 - dice_coef: 0.3073 - iou_coef: 0.1727 - val_loss: -0.4343 - val_dice_coef: 0.5308 - val_iou_coef: 0.3658
#
# Epoch 00016: val_loss improved from -0.40149 to -0.43427, saving model to files/model.h5
# Epoch 17/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2416 - dice_coef: 0.3256 - iou_coef: 0.1856 - val_loss: -0.4131 - val_dice_coef: 0.5008 - val_iou_coef: 0.3586
#
# Epoch 00017: val_loss did not improve from -0.43427
# Epoch 18/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2469 - dice_coef: 0.3317 - iou_coef: 0.1904 - val_loss: -0.4570 - val_dice_coef: 0.5602 - val_iou_coef: 0.3893
#
# Epoch 00018: val_loss improved from -0.43427 to -0.45705, saving model to files/model.h5
# Epoch 19/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2328 - dice_coef: 0.3177 - iou_coef: 0.1762 - val_loss: -0.4687 - val_dice_coef: 0.5812 - val_iou_coef: 0.3891
#
# Epoch 00019: val_loss improved from -0.45705 to -0.46871, saving model to files/model.h5
# Epoch 20/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2466 - dice_coef: 0.3322 - iou_coef: 0.1896 - val_loss: -0.4493 - val_dice_coef: 0.5421 - val_iou_coef: 0.3863
#
# Epoch 00020: val_loss did not improve from -0.46871
# Epoch 21/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2376 - dice_coef: 0.3228 - iou_coef: 0.1808 - val_loss: -0.4423 - val_dice_coef: 0.5462 - val_iou_coef: 0.3736
#
# Epoch 00021: val_loss did not improve from -0.46871
# Epoch 22/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2494 - dice_coef: 0.3354 - iou_coef: 0.1921 - val_loss: -0.3165 - val_dice_coef: 0.3860 - val_iou_coef: 0.2723
#
# Epoch 00022: val_loss did not improve from -0.46871
# Epoch 23/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2460 - dice_coef: 0.3274 - iou_coef: 0.1918 - val_loss: -0.1125 - val_dice_coef: 0.1684 - val_iou_coef: 0.0741
#
# Epoch 00023: val_loss did not improve from -0.46871
# Epoch 24/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2555 - dice_coef: 0.3443 - iou_coef: 0.1962 - val_loss: -0.4884 - val_dice_coef: 0.5768 - val_iou_coef: 0.4282
#
# Epoch 00024: val_loss improved from -0.46871 to -0.48844, saving model to files/model.h5
# Epoch 25/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2577 - dice_coef: 0.3436 - iou_coef: 0.2004 - val_loss: -0.4817 - val_dice_coef: 0.5859 - val_iou_coef: 0.4101
#
# Epoch 00025: val_loss did not improve from -0.48844
# Epoch 26/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2450 - dice_coef: 0.3300 - iou_coef: 0.1883 - val_loss: -0.3921 - val_dice_coef: 0.4756 - val_iou_coef: 0.3355
#
# Epoch 00026: val_loss did not improve from -0.48844
# Epoch 27/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2438 - dice_coef: 0.3283 - iou_coef: 0.1875 - val_loss: -0.4688 - val_dice_coef: 0.5713 - val_iou_coef: 0.4021
#
# Epoch 00027: val_loss did not improve from -0.48844
# Epoch 28/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2577 - dice_coef: 0.3490 - iou_coef: 0.1969 - val_loss: -0.4665 - val_dice_coef: 0.5687 - val_iou_coef: 0.3954
#
# Epoch 00028: val_loss did not improve from -0.48844
# Epoch 29/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2551 - dice_coef: 0.3439 - iou_coef: 0.1959 - val_loss: -0.4680 - val_dice_coef: 0.5823 - val_iou_coef: 0.3940
#
# Epoch 00029: val_loss did not improve from -0.48844
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 30/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2646 - dice_coef: 0.3547 - iou_coef: 0.2045 - val_loss: -0.5226 - val_dice_coef: 0.6411 - val_iou_coef: 0.4419
#
# Epoch 00030: val_loss improved from -0.48844 to -0.52255, saving model to files/model.h5
# Epoch 31/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2766 - dice_coef: 0.3705 - iou_coef: 0.2140 - val_loss: -0.5449 - val_dice_coef: 0.6624 - val_iou_coef: 0.4647
#
# Epoch 00031: val_loss improved from -0.52255 to -0.54492, saving model to files/model.h5
# Epoch 32/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2747 - dice_coef: 0.3677 - iou_coef: 0.2126 - val_loss: -0.5560 - val_dice_coef: 0.6709 - val_iou_coef: 0.4743
#
# Epoch 00032: val_loss improved from -0.54492 to -0.55601, saving model to files/model.h5
# Epoch 33/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2750 - dice_coef: 0.3661 - iou_coef: 0.2143 - val_loss: -0.5576 - val_dice_coef: 0.6697 - val_iou_coef: 0.4791
#
# Epoch 00033: val_loss improved from -0.55601 to -0.55760, saving model to files/model.h5
# Epoch 34/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2713 - dice_coef: 0.3655 - iou_coef: 0.2084 - val_loss: -0.5542 - val_dice_coef: 0.6659 - val_iou_coef: 0.4771
#
# Epoch 00034: val_loss did not improve from -0.55760
# Epoch 35/500
# 115/115 [==============================] - 34s 290ms/step - loss: -0.2647 - dice_coef: 0.3545 - iou_coef: 0.2049 - val_loss: -0.5499 - val_dice_coef: 0.6608 - val_iou_coef: 0.4750
#
# Epoch 00035: val_loss did not improve from -0.55760
# Epoch 36/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2792 - dice_coef: 0.3731 - iou_coef: 0.2167 - val_loss: -0.5549 - val_dice_coef: 0.6650 - val_iou_coef: 0.4774
#
# Epoch 00036: val_loss did not improve from -0.55760
# Epoch 37/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2845 - dice_coef: 0.3890 - iou_coef: 0.2149 - val_loss: -0.5506 - val_dice_coef: 0.6603 - val_iou_coef: 0.4745
#
# Epoch 00037: val_loss did not improve from -0.55760
# Epoch 38/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2737 - dice_coef: 0.3667 - iou_coef: 0.2117 - val_loss: -0.5498 - val_dice_coef: 0.6619 - val_iou_coef: 0.4709
#
# Epoch 00038: val_loss did not improve from -0.55760
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 39/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2816 - dice_coef: 0.3788 - iou_coef: 0.2168 - val_loss: -0.5475 - val_dice_coef: 0.6600 - val_iou_coef: 0.4698
#
# Epoch 00039: val_loss did not improve from -0.55760
# Epoch 40/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2770 - dice_coef: 0.3696 - iou_coef: 0.2153 - val_loss: -0.5463 - val_dice_coef: 0.6586 - val_iou_coef: 0.4693
#
# Epoch 00040: val_loss did not improve from -0.55760
# Epoch 41/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2783 - dice_coef: 0.3719 - iou_coef: 0.2159 - val_loss: -0.5469 - val_dice_coef: 0.6594 - val_iou_coef: 0.4697
#
# Epoch 00041: val_loss did not improve from -0.55760
# Epoch 42/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2700 - dice_coef: 0.3595 - iou_coef: 0.2103 - val_loss: -0.5470 - val_dice_coef: 0.6594 - val_iou_coef: 0.4702
#
# Epoch 00042: val_loss did not improve from -0.55760
# Epoch 43/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2707 - dice_coef: 0.3646 - iou_coef: 0.2081 - val_loss: -0.5465 - val_dice_coef: 0.6585 - val_iou_coef: 0.4703
#
# Epoch 00043: val_loss did not improve from -0.55760
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 44/500
# 115/115 [==============================] - 34s 289ms/step - loss: -0.2657 - dice_coef: 0.3572 - iou_coef: 0.2047 - val_loss: -0.5470 - val_dice_coef: 0.6590 - val_iou_coef: 0.4707
#
# Epoch 00044: val_loss did not improve from -0.55760
# Epoch 45/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2902 - dice_coef: 0.3859 - iou_coef: 0.2263 - val_loss: -0.5470 - val_dice_coef: 0.6590 - val_iou_coef: 0.4708
#
# Epoch 00045: val_loss did not improve from -0.55760
# Epoch 46/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2811 - dice_coef: 0.3736 - iou_coef: 0.2194 - val_loss: -0.5467 - val_dice_coef: 0.6587 - val_iou_coef: 0.4705
#
# Epoch 00046: val_loss did not improve from -0.55760
# Epoch 47/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2864 - dice_coef: 0.3858 - iou_coef: 0.2201 - val_loss: -0.5474 - val_dice_coef: 0.6594 - val_iou_coef: 0.4710
#
# Epoch 00047: val_loss did not improve from -0.55760
# Epoch 48/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2745 - dice_coef: 0.3683 - iou_coef: 0.2120 - val_loss: -0.5471 - val_dice_coef: 0.6591 - val_iou_coef: 0.4709
#
# Epoch 00048: val_loss did not improve from -0.55760
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 49/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2787 - dice_coef: 0.3744 - iou_coef: 0.2148 - val_loss: -0.5471 - val_dice_coef: 0.6590 - val_iou_coef: 0.4710
#
# Epoch 00049: val_loss did not improve from -0.55760
# Epoch 50/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2689 - dice_coef: 0.3599 - iou_coef: 0.2083 - val_loss: -0.5464 - val_dice_coef: 0.6582 - val_iou_coef: 0.4704
#
# Epoch 00050: val_loss did not improve from -0.55760
# Epoch 51/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2729 - dice_coef: 0.3689 - iou_coef: 0.2088 - val_loss: -0.5465 - val_dice_coef: 0.6583 - val_iou_coef: 0.4705
#
# Epoch 00051: val_loss did not improve from -0.55760
# Epoch 52/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2844 - dice_coef: 0.3825 - iou_coef: 0.2190 - val_loss: -0.5474 - val_dice_coef: 0.6591 - val_iou_coef: 0.4713
#
# Epoch 00052: val_loss did not improve from -0.55760
# Epoch 53/500
# 115/115 [==============================] - 34s 290ms/step - loss: -0.2789 - dice_coef: 0.3770 - iou_coef: 0.2136 - val_loss: -0.5470 - val_dice_coef: 0.6588 - val_iou_coef: 0.4710
#
# Epoch 00053: val_loss did not improve from -0.55760
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 54/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2841 - dice_coef: 0.3828 - iou_coef: 0.2182 - val_loss: -0.5477 - val_dice_coef: 0.6594 - val_iou_coef: 0.4715
#
# Epoch 00054: val_loss did not improve from -0.55760
# Epoch 55/500
# 115/115 [==============================] - 33s 286ms/step - loss: -0.2795 - dice_coef: 0.3761 - iou_coef: 0.2150 - val_loss: -0.5475 - val_dice_coef: 0.6593 - val_iou_coef: 0.4713
#
# Epoch 00055: val_loss did not improve from -0.55760
# Epoch 56/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2675 - dice_coef: 0.3574 - iou_coef: 0.2075 - val_loss: -0.5474 - val_dice_coef: 0.6591 - val_iou_coef: 0.4712
#
# Epoch 00056: val_loss did not improve from -0.55760
# Epoch 57/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2834 - dice_coef: 0.3782 - iou_coef: 0.2202 - val_loss: -0.5478 - val_dice_coef: 0.6596 - val_iou_coef: 0.4715
#
# Epoch 00057: val_loss did not improve from -0.55760
# Epoch 58/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2883 - dice_coef: 0.3830 - iou_coef: 0.2251 - val_loss: -0.5475 - val_dice_coef: 0.6592 - val_iou_coef: 0.4713
#
# Epoch 00058: val_loss did not improve from -0.55760
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 59/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2779 - dice_coef: 0.3742 - iou_coef: 0.2137 - val_loss: -0.5472 - val_dice_coef: 0.6589 - val_iou_coef: 0.4711
#
# Epoch 00059: val_loss did not improve from -0.55760
# Epoch 60/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2771 - dice_coef: 0.3723 - iou_coef: 0.2136 - val_loss: -0.5474 - val_dice_coef: 0.6591 - val_iou_coef: 0.4713
#
# Epoch 00060: val_loss did not improve from -0.55760
# Epoch 61/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2789 - dice_coef: 0.3728 - iou_coef: 0.2163 - val_loss: -0.5472 - val_dice_coef: 0.6590 - val_iou_coef: 0.4712
#
# Epoch 00061: val_loss did not improve from -0.55760
# Epoch 62/500
# 115/115 [==============================] - 34s 290ms/step - loss: -0.2662 - dice_coef: 0.3586 - iou_coef: 0.2046 - val_loss: -0.5472 - val_dice_coef: 0.6590 - val_iou_coef: 0.4711
#
# Epoch 00062: val_loss did not improve from -0.55760
# Epoch 63/500
# 115/115 [==============================] - 33s 287ms/step - loss: -0.2845 - dice_coef: 0.3817 - iou_coef: 0.2197 - val_loss: -0.5472 - val_dice_coef: 0.6589 - val_iou_coef: 0.4711
# Epoch 00063: val_loss did not improve from -0.55760
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 64/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2852 - dice_coef: 0.3806 - iou_coef: 0.2215 - val_loss: -0.5474 - val_dice_coef: 0.6592 - val_iou_coef: 0.4713
#
# Epoch 00064: val_loss did not improve from -0.55760
# Epoch 65/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2856 - dice_coef: 0.3842 - iou_coef: 0.2200 - val_loss: -0.5475 - val_dice_coef: 0.6593 - val_iou_coef: 0.4714
#
# Epoch 00065: val_loss did not improve from -0.55760
# Epoch 66/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2770 - dice_coef: 0.3693 - iou_coef: 0.2154 - val_loss: -0.5477 - val_dice_coef: 0.6595 - val_iou_coef: 0.4716
#
# Epoch 00066: val_loss did not improve from -0.55760
# Epoch 67/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2857 - dice_coef: 0.3829 - iou_coef: 0.2209 - val_loss: -0.5478 - val_dice_coef: 0.6596 - val_iou_coef: 0.4717
#
# Epoch 00067: val_loss did not improve from -0.55760
# Epoch 68/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2808 - dice_coef: 0.3753 - iou_coef: 0.2178 - val_loss: -0.5483 - val_dice_coef: 0.6602 - val_iou_coef: 0.4722
#
# Epoch 00068: val_loss did not improve from -0.55760
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 69/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2773 - dice_coef: 0.3738 - iou_coef: 0.2130 - val_loss: -0.5480 - val_dice_coef: 0.6599 - val_iou_coef: 0.4719
#
# Epoch 00069: val_loss did not improve from -0.55760
# Epoch 70/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2752 - dice_coef: 0.3728 - iou_coef: 0.2101 - val_loss: -0.5483 - val_dice_coef: 0.6602 - val_iou_coef: 0.4722
#
# Epoch 00070: val_loss did not improve from -0.55760
# Epoch 71/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2845 - dice_coef: 0.3806 - iou_coef: 0.2204 - val_loss: -0.5482 - val_dice_coef: 0.6601 - val_iou_coef: 0.4721
#
# Epoch 00071: val_loss did not improve from -0.55760
# Epoch 72/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2760 - dice_coef: 0.3696 - iou_coef: 0.2135 - val_loss: -0.5478 - val_dice_coef: 0.6596 - val_iou_coef: 0.4718
#
# Epoch 00072: val_loss did not improve from -0.55760
# Epoch 73/500
# 115/115 [==============================] - 33s 287ms/step - loss: -0.2818 - dice_coef: 0.3775 - iou_coef: 0.2181 - val_loss: -0.5482 - val_dice_coef: 0.6600 - val_iou_coef: 0.4721
#
# Epoch 00073: val_loss did not improve from -0.55760
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 74/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2745 - dice_coef: 0.3694 - iou_coef: 0.2112 - val_loss: -0.5477 - val_dice_coef: 0.6593 - val_iou_coef: 0.4718
#
# Epoch 00074: val_loss did not improve from -0.55760
# Epoch 75/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2780 - dice_coef: 0.3748 - iou_coef: 0.2134 - val_loss: -0.5476 - val_dice_coef: 0.6592 - val_iou_coef: 0.4718
#
# Epoch 00075: val_loss did not improve from -0.55760
# Epoch 76/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2679 - dice_coef: 0.3604 - iou_coef: 0.2062 - val_loss: -0.5477 - val_dice_coef: 0.6593 - val_iou_coef: 0.4719
#
# Epoch 00076: val_loss did not improve from -0.55760
# Epoch 77/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2821 - dice_coef: 0.3795 - iou_coef: 0.2171 - val_loss: -0.5482 - val_dice_coef: 0.6598 - val_iou_coef: 0.4724
#
# Epoch 00077: val_loss did not improve from -0.55760
# Epoch 78/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2785 - dice_coef: 0.3759 - iou_coef: 0.2136 - val_loss: -0.5482 - val_dice_coef: 0.6598 - val_iou_coef: 0.4723
#
# Epoch 00078: val_loss did not improve from -0.55760
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 79/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2664 - dice_coef: 0.3576 - iou_coef: 0.2056 - val_loss: -0.5482 - val_dice_coef: 0.6598 - val_iou_coef: 0.4724
#
# Epoch 00079: val_loss did not improve from -0.55760
# Epoch 80/500
# 115/115 [==============================] - 33s 288ms/step - loss: -0.2835 - dice_coef: 0.3831 - iou_coef: 0.2171 - val_loss: -0.5480 - val_dice_coef: 0.6596 - val_iou_coef: 0.4722
#
# Epoch 00080: val_loss did not improve from -0.55760
# Epoch 81/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2737 - dice_coef: 0.3706 - iou_coef: 0.2090 - val_loss: -0.5479 - val_dice_coef: 0.6595 - val_iou_coef: 0.4722
#
# Epoch 00081: val_loss did not improve from -0.55760
# Epoch 82/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2770 - dice_coef: 0.3682 - iou_coef: 0.2162 - val_loss: -0.5477 - val_dice_coef: 0.6593 - val_iou_coef: 0.4721
#
# Epoch 00082: val_loss did not improve from -0.55760
# Epoch 83/500
# 115/115 [==============================] - 33s 289ms/step - loss: -0.2708 - dice_coef: 0.3606 - iou_coef: 0.2110 - val_loss: -0.5483 - val_dice_coef: 0.6599 - val_iou_coef: 0.4725
#
# Epoch 00083: val_loss did not improve from -0.55760
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1e-07.

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['dice_coef'], label='Dice Coefficient')
plt.plot(history.history['val_dice_coef'], label='Validation Dice Coefficient')
plt.title('Dice Coefficient Curves')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.show()

# %%
plt.plot(history.history['lr'], label='Learning Rate')
plt.title('Learning Rate Schedule')
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.legend()
plt.show()

# %%
from tqdm import tqdm
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"


""" Creating a directory """

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
import pandas as pd
if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
    with CustomObjectScope({'loss': loss, 'dice_coef': dice_coef, 'iou_coef': iou_coef}):
        model = tf.keras.models.load_model(os.path.join("files", "model.h5"))

    """ Dataset """
    dataset_path = "/home/akshatt/nandan/dataset/dataset/archive/"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    """ Prediction and Evaluation """
    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_y)):
        """ Extracting the name """
        name = x.split("/")[-1]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR) ## [H, w, 3]
        image = cv2.resize(image, (W, H))       ## [H, w, 3]
        x = image/255.0                         ## [H, w, 3]
        x = np.expand_dims(x, axis=0)           ## [1, H, w, 3]

        """ Reading the mask """
        mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (W, H))

        """ Prediction """
        y_pred = model.predict(x, verbose=0)[0]
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred >= 0.5
        y_pred = y_pred.astype(np.int32)

        """ Saving the prediction """
        save_image_path = os.path.join("results", name)
        save_results(image, mask, y_pred, save_image_path)

        """ Flatten the array """
        mask = mask/255.0
        mask = (mask > 0.5).astype(np.int32).flatten()
        y_pred = y_pred.flatten()

        """ Calculating the metrics values """
        f1_value = f1_score(mask, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(mask, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
        precision_value = precision_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
        y_pred = y_pred.astype(np.float32)
        mask = mask.astype(np.float32).flatten()
        dice_value = dice_coef(mask, y_pred)
        SCORE.append([name, f1_value, jac_value, recall_value, precision_value, dice_value])

    """ Metrics values """
    score = [s[1:]for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"F1: {score[0]:0.5f}")
    print(f"Jaccard: {score[1]:0.5f}")
    print(f"Recall: {score[2]:0.5f}")
    print(f"Precision: {score[3]:0.5f}")
    print(f"dice_value: {score[4]:0.5f}")

    df = pd.DataFrame(SCORE, columns=["Image", "F1", "Jaccard", "Recall", "Precision", "Dice_value"])
    df.to_csv("files/score.csv")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 612/612 [00:53<00:00, 11.44it/s]
# F1: 0.59317
# Jaccard: 0.46799
# Recall: 0.76089
# Precision: 0.53460
# dice_value: 0.59368
