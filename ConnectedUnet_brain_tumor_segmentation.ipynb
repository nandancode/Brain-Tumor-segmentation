# %%
import os
# os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Conv2DTranspose, concatenate, Input
from tensorflow.keras.models import Model
# Out:
# 2023-08-15 18:09:01.603816: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
from tensorflow.keras.layers import Add
def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def build_unet(input_shape):
    inputs = Input(input_shape)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = aspp_block(pool4, 1024)
    
    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(up6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    
    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(up7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(up8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    
    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(up9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)
    
    down10 = concatenate([Conv2D(64, (3, 3), activation='relu', padding='same')(conv9), conv9], axis=3)
    conv10 = Conv2D(64, (3, 3), activation='relu', padding='same')(down10)
    conv10 = BatchNormalization()(conv10)
    conv10 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv10)
    conv10 = BatchNormalization()(conv10)    
    pool10 = MaxPooling2D(pool_size=(2, 2))(conv10)

    down11 = concatenate([Conv2D(128, (3, 3), activation='relu', padding='same')(pool10), conv8], axis=3)
    conv11 = Conv2D(128, (3, 3), activation='relu', padding='same')(down11)
    conv11 = BatchNormalization()(conv11)
    conv11 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv11)
    conv11 = BatchNormalization()(conv11)   
    pool11 = MaxPooling2D(pool_size=(2, 2))(conv11)
    
    down12 = concatenate([Conv2D(256, (3, 3), activation='relu', padding='same')(pool11), conv7], axis=3)
    conv12 = Conv2D(256, (3, 3), activation='relu', padding='same')(down12)
    conv12 = BatchNormalization()(conv12)
    conv12 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv12)    
    conv12 = BatchNormalization()(conv12)
    pool12 = MaxPooling2D(pool_size=(2, 2))(conv12)

    down13 = concatenate([Conv2D(512, (3, 3), activation='relu', padding='same')(pool12), conv6], axis=3)
    conv13 = Conv2D(512, (3, 3), activation='relu', padding='same')(down13)
    conv13 = BatchNormalization()(conv13)
    conv13 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv13)  
    conv13 = BatchNormalization()(conv13)    
    pool13 = MaxPooling2D(pool_size=(2, 2))(conv13)
    
    conv14 = aspp_block(pool13, 1024)
    
    up15 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(conv14), conv13], axis=3)
    conv15 = Conv2D(512, (3, 3), activation='relu', padding='same')(up15)
    conv15 = BatchNormalization()(conv15)    
    conv15 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv15)
    conv15 = BatchNormalization()(conv15) 
    
    up16 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv15), conv12], axis=3)
    conv16 = Conv2D(256, (3, 3), activation='relu', padding='same')(up16)
    conv16 = BatchNormalization()(conv16)     
    conv16 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv16)
    conv16 = BatchNormalization()(conv16)      

    up17 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv16), conv11], axis=3)
    conv17 = Conv2D(128, (3, 3), activation='relu', padding='same')(up17)
    conv17 = BatchNormalization()(conv17)      
    conv17 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv17)
    conv17 = BatchNormalization()(conv17)  
    
    up18 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv17), conv10], axis=3)
    conv18 = Conv2D(64, (3, 3), activation='relu', padding='same')(up18)
    conv18 = BatchNormalization()(conv18)      
    conv18 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv18)
    conv18 = BatchNormalization()(conv18)    
    
    conv18 = aspp_block(conv18, 64)
        
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv18)
    
    model = Model(inputs, outputs, name="UNET")
    return model

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = build_unet(input_shape)
    model.summary()
# Out:
# 2023-08-15 18:09:20.917363: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-08-15 18:09:20.918343: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-08-15 18:09:21.084643: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-08-15 18:09:21.084667: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-15 18:09:21.086406: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-08-15 18:09:21.086438: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-08-15 18:09:21.088177: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-08-15 18:09:21.088430: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-08-15 18:09:21.090329: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-08-15 18:09:21.091256: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-08-15 18:09:21.095553: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-08-15 18:09:21.099479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-08-15 18:09:21.100245: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-15 18:09:21.103708: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-08-15 18:09:21.105898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:0a:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2023-08-15 18:09:21.105921: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-15 18:09:21.105939: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-08-15 18:09:21.105955: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-08-15 18:09:21.105969: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-08-15 18:09:21.105983: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-08-15 18:09:21.105997: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-08-15 18:09:21.106011: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-08-15 18:09:21.106025: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-08-15 18:09:21.109816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-08-15 18:09:21.109849: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-08-15 18:09:21.695231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-08-15 18:09:21.695273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2023-08-15 18:09:21.695280: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2023-08-15 18:09:21.701138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30130 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:0a:00.0, compute capability: 7.0)
# Model: "UNET"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 1024) 4096        conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 1024) 4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 1024) 0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 1024) 1049600     add[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  2097664     conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 128 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 256, 256, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 128 0           conv2d_21[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 64) 256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 256, 64) 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 256 0           conv2d_24[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 128 295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 128 512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 128 512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 512)  0           conv2d_27[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 256)  1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 1024) 0           conv2d_30[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 512)  2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 512)  2048        conv2d_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 512)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 1024) 4096        conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 1024) 4096        conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 1024) 4096        conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 1024) 4096        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 1024) 0           batch_normalization_28[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_30[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 16, 16, 1024) 1049600     add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 512)  2097664     conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 1024) 0           conv2d_transpose_4[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 512)  2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 512)  2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 256)  524544      batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_5[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 64, 256)  1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64, 64, 256)  1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 128 131200      batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 256 0           conv2d_transpose_6[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 128 295040      concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 128, 128, 128 512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 128, 128, 128 512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 64) 32832       batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 256, 128 0           conv2d_transpose_7[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 256, 256, 64) 256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 256, 256, 64) 256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 256, 256, 64) 256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 256, 256, 64) 256         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 256, 256, 64) 256         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 256, 256, 64) 256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 256, 64) 0           batch_normalization_40[0][0]
#                                                                  batch_normalization_41[0][0]
#                                                                  batch_normalization_42[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 256, 256, 64) 4160        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 256, 256, 1)  65          conv2d_50[0][0]
# ==================================================================================================
# Total params: 80,123,265
# Trainable params: 80,091,009
# Non-trainable params: 32,256
# __________________________________________________________________________________________________

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K

# %%
""" Global parameters """
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
H = 256
W = 256
smooth = 1.

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def load_dataset(path, split=0.2):
    images = sorted(glob(os.path.join(path, "images", "*.png")))
    masks = sorted(glob(os.path.join(path, "masks", "*.png")))

    split_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (h, w)
    x = cv2.resize(x, (W, H))   ## (h, w)
    x = x / 255.0               ## (h, w)
    x = x.astype(np.float32)    ## (h, w)
    x = np.expand_dims(x, axis=-1)## (h, w, 1)
    return x

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
augmentation_args = dict(
    rotation_range=0.2,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    fill_mode='nearest'
)

image_datagen = ImageDataGenerator(**augmentation_args)
mask_datagen = ImageDataGenerator(**augmentation_args)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def read_and_augment_image(image_path):
    image = read_image(image_path)
    augmented_image = image_datagen.random_transform(image)
    return augmented_image

def read_and_augment_mask(mask_path):
    mask = read_mask(mask_path)
    augmented_mask = mask_datagen.random_transform(mask)
    return augmented_mask

def tf_parse_augmented(x, y):
    def _parse_augmented(x, y):
        x = read_and_augment_image(x)
        y = read_and_augment_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse_augmented, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset_augmented(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse_augmented)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def iou_coef(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  return iou


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def loss(y_true, y_pred):
    return -(0.4*dice_coef(y_true, y_pred)+0.6*iou_coef(y_true, y_pred))

# %%
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth = True
# config.log_device_placement = True
# sess = tf.compat.v1.Session(config=config)

# config = tf.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.6  # 0.6 sometimes works better for folks
# keras.backend.tensorflow_backend.set_session(tf.Session(config=config))

os.environ["CUDA_VISIBLE_DEVICES"] = "2"

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 16
    lr = 1e-4
    num_epochs = 500
    model_path = os.path.join("files", "model2.h5")
    csv_path = os.path.join("files", "log2.csv")

    """ Dataset """
    dataset_path = "/home/akshatt/nandan/dataset/dataset/archive/"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test : {len(test_x)} - {len(test_y)}")
    
#     train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
#     valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
    
    train_dataset = tf_dataset_augmented(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    """ Model """
    model = build_unet((H, W, 3))
    model.compile(loss=loss, optimizer=Adam(lr), metrics=[dice_coef, iou_coef])

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=False),
    ]

    history = model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 1840 - 1840
# Valid: 612 - 612
# Test : 612 - 612
# 2023-08-15 18:09:47.030601: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-08-15 18:09:47.049335: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2195045000 Hz
# Epoch 1/500
# 2023-08-15 18:09:51.773522: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-08-15 18:09:52.871702: W tensorflow/stream_executor/gpu/asm_compiler.cc:98] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 2023-08-15 18:09:52.997871: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 115/115 [==============================] - 116s 920ms/step - loss: -0.0887 - dice_coef: 0.1214 - iou_coef: 0.0668 - val_loss: -0.0691 - val_dice_coef: 0.0963 - val_iou_coef: 0.0508
#
# Epoch 00001: val_loss improved from inf to -0.06910, saving model to files/model2.h5
# Epoch 2/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.1673 - dice_coef: 0.2236 - iou_coef: 0.1297 - val_loss: -0.0012 - val_dice_coef: 1.9684e-04 - val_iou_coef: 0.0018
#
# Epoch 00002: val_loss did not improve from -0.06910
# Epoch 3/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.1861 - dice_coef: 0.2501 - iou_coef: 0.1435 - val_loss: -0.0011 - val_dice_coef: 1.1359e-04 - val_iou_coef: 0.0018
#
# Epoch 00003: val_loss did not improve from -0.06910
# Epoch 4/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2058 - dice_coef: 0.2784 - iou_coef: 0.1573 - val_loss: -0.0274 - val_dice_coef: 0.0389 - val_iou_coef: 0.0195
#
# Epoch 00004: val_loss did not improve from -0.06910
# Epoch 5/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2082 - dice_coef: 0.2780 - iou_coef: 0.1616 - val_loss: -0.1834 - val_dice_coef: 0.2491 - val_iou_coef: 0.1377
#
# Epoch 00005: val_loss improved from -0.06910 to -0.18344, saving model to files/model2.h5
# Epoch 6/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2160 - dice_coef: 0.2892 - iou_coef: 0.1671 - val_loss: -0.3091 - val_dice_coef: 0.3892 - val_iou_coef: 0.2509
#
# Epoch 00006: val_loss improved from -0.18344 to -0.30914, saving model to files/model2.h5
# Epoch 7/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2167 - dice_coef: 0.2922 - iou_coef: 0.1663 - val_loss: -0.3008 - val_dice_coef: 0.3656 - val_iou_coef: 0.2527
#
# Epoch 00007: val_loss did not improve from -0.30914
# Epoch 8/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2257 - dice_coef: 0.3049 - iou_coef: 0.1729 - val_loss: -0.1626 - val_dice_coef: 0.2203 - val_iou_coef: 0.1228
#
# Epoch 00008: val_loss did not improve from -0.30914
# Epoch 9/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2237 - dice_coef: 0.3035 - iou_coef: 0.1705 - val_loss: -0.3159 - val_dice_coef: 0.3987 - val_iou_coef: 0.2593
#
# Epoch 00009: val_loss improved from -0.30914 to -0.31590, saving model to files/model2.h5
# Epoch 10/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2286 - dice_coef: 0.3025 - iou_coef: 0.1794 - val_loss: -0.3831 - val_dice_coef: 0.4743 - val_iou_coef: 0.3151
#
# Epoch 00010: val_loss improved from -0.31590 to -0.38306, saving model to files/model2.h5
# Epoch 11/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2424 - dice_coef: 0.3243 - iou_coef: 0.1878 - val_loss: -0.4170 - val_dice_coef: 0.5229 - val_iou_coef: 0.3386
#
# Epoch 00011: val_loss improved from -0.38306 to -0.41696, saving model to files/model2.h5
# Epoch 12/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2446 - dice_coef: 0.3274 - iou_coef: 0.1894 - val_loss: -0.3474 - val_dice_coef: 0.4306 - val_iou_coef: 0.2928
#
# Epoch 00012: val_loss did not improve from -0.41696
# Epoch 13/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2375 - dice_coef: 0.3141 - iou_coef: 0.1863 - val_loss: -0.2739 - val_dice_coef: 0.3413 - val_iou_coef: 0.2278
#
# Epoch 00013: val_loss did not improve from -0.41696
# Epoch 14/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2365 - dice_coef: 0.3125 - iou_coef: 0.1858 - val_loss: -0.2825 - val_dice_coef: 0.3574 - val_iou_coef: 0.2290
#
# Epoch 00014: val_loss did not improve from -0.41696
# Epoch 15/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2402 - dice_coef: 0.3190 - iou_coef: 0.1876 - val_loss: -0.3645 - val_dice_coef: 0.4550 - val_iou_coef: 0.3001
#
# Epoch 00015: val_loss did not improve from -0.41696
# Epoch 16/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2472 - dice_coef: 0.3229 - iou_coef: 0.1968 - val_loss: -0.3762 - val_dice_coef: 0.4628 - val_iou_coef: 0.3140
#
# Epoch 00016: val_loss did not improve from -0.41696
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 17/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2640 - dice_coef: 0.3503 - iou_coef: 0.2065 - val_loss: -0.5005 - val_dice_coef: 0.6027 - val_iou_coef: 0.4284
#
# Epoch 00017: val_loss improved from -0.41696 to -0.50052, saving model to files/model2.h5
# Epoch 18/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2686 - dice_coef: 0.3560 - iou_coef: 0.2103 - val_loss: -0.5089 - val_dice_coef: 0.6122 - val_iou_coef: 0.4358
#
# Epoch 00018: val_loss improved from -0.50052 to -0.50891, saving model to files/model2.h5
# Epoch 19/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2562 - dice_coef: 0.3421 - iou_coef: 0.1989 - val_loss: -0.5166 - val_dice_coef: 0.6255 - val_iou_coef: 0.4390
#
# Epoch 00019: val_loss improved from -0.50891 to -0.51658, saving model to files/model2.h5
# Epoch 20/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2700 - dice_coef: 0.3602 - iou_coef: 0.2098 - val_loss: -0.5111 - val_dice_coef: 0.6158 - val_iou_coef: 0.4373
#
# Epoch 00020: val_loss did not improve from -0.51658
# Epoch 21/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2563 - dice_coef: 0.3436 - iou_coef: 0.1982 - val_loss: -0.5249 - val_dice_coef: 0.6339 - val_iou_coef: 0.4482
#
# Epoch 00021: val_loss improved from -0.51658 to -0.52495, saving model to files/model2.h5
# Epoch 22/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2658 - dice_coef: 0.3530 - iou_coef: 0.2076 - val_loss: -0.5187 - val_dice_coef: 0.6264 - val_iou_coef: 0.4418
#
# Epoch 00022: val_loss did not improve from -0.52495
# Epoch 23/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2638 - dice_coef: 0.3466 - iou_coef: 0.2086 - val_loss: -0.4910 - val_dice_coef: 0.5944 - val_iou_coef: 0.4159
#
# Epoch 00023: val_loss did not improve from -0.52495
# Epoch 24/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2678 - dice_coef: 0.3558 - iou_coef: 0.2091 - val_loss: -0.5205 - val_dice_coef: 0.6307 - val_iou_coef: 0.4413
#
# Epoch 00024: val_loss did not improve from -0.52495
# Epoch 25/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2800 - dice_coef: 0.3703 - iou_coef: 0.2198 - val_loss: -0.5161 - val_dice_coef: 0.6269 - val_iou_coef: 0.4362
#
# Epoch 00025: val_loss did not improve from -0.52495
# Epoch 26/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2581 - dice_coef: 0.3420 - iou_coef: 0.2021 - val_loss: -0.5233 - val_dice_coef: 0.6318 - val_iou_coef: 0.4456
#
# Epoch 00026: val_loss did not improve from -0.52495
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 27/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2604 - dice_coef: 0.3466 - iou_coef: 0.2029 - val_loss: -0.5170 - val_dice_coef: 0.6248 - val_iou_coef: 0.4394
#
# Epoch 00027: val_loss did not improve from -0.52495
# Epoch 28/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2768 - dice_coef: 0.3689 - iou_coef: 0.2154 - val_loss: -0.5160 - val_dice_coef: 0.6245 - val_iou_coef: 0.4379
#
# Epoch 00028: val_loss did not improve from -0.52495
# Epoch 29/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2728 - dice_coef: 0.3625 - iou_coef: 0.2130 - val_loss: -0.5146 - val_dice_coef: 0.6230 - val_iou_coef: 0.4365
#
# Epoch 00029: val_loss did not improve from -0.52495
# Epoch 30/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2733 - dice_coef: 0.3628 - iou_coef: 0.2136 - val_loss: -0.5143 - val_dice_coef: 0.6212 - val_iou_coef: 0.4371
#
# Epoch 00030: val_loss did not improve from -0.52495
# Epoch 31/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2824 - dice_coef: 0.3721 - iou_coef: 0.2226 - val_loss: -0.5174 - val_dice_coef: 0.6243 - val_iou_coef: 0.4403
#
# Epoch 00031: val_loss did not improve from -0.52495
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 32/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2773 - dice_coef: 0.3667 - iou_coef: 0.2177 - val_loss: -0.5161 - val_dice_coef: 0.6230 - val_iou_coef: 0.4390
#
# Epoch 00032: val_loss did not improve from -0.52495
# Epoch 33/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2770 - dice_coef: 0.3654 - iou_coef: 0.2180 - val_loss: -0.5153 - val_dice_coef: 0.6221 - val_iou_coef: 0.4382
#
# Epoch 00033: val_loss did not improve from -0.52495
# Epoch 34/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2750 - dice_coef: 0.3661 - iou_coef: 0.2143 - val_loss: -0.5153 - val_dice_coef: 0.6221 - val_iou_coef: 0.4382
#
# Epoch 00034: val_loss did not improve from -0.52495
# Epoch 35/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2677 - dice_coef: 0.3551 - iou_coef: 0.2094 - val_loss: -0.5154 - val_dice_coef: 0.6221 - val_iou_coef: 0.4383
#
# Epoch 00035: val_loss did not improve from -0.52495
# Epoch 36/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2802 - dice_coef: 0.3712 - iou_coef: 0.2195 - val_loss: -0.5154 - val_dice_coef: 0.6222 - val_iou_coef: 0.4383
#
# Epoch 00036: val_loss did not improve from -0.52495
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 37/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2798 - dice_coef: 0.3762 - iou_coef: 0.2155 - val_loss: -0.5147 - val_dice_coef: 0.6214 - val_iou_coef: 0.4376
#
# Epoch 00037: val_loss did not improve from -0.52495
# Epoch 38/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2720 - dice_coef: 0.3622 - iou_coef: 0.2119 - val_loss: -0.5153 - val_dice_coef: 0.6221 - val_iou_coef: 0.4382
#
# Epoch 00038: val_loss did not improve from -0.52495
# Epoch 39/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2795 - dice_coef: 0.3701 - iou_coef: 0.2192 - val_loss: -0.5150 - val_dice_coef: 0.6217 - val_iou_coef: 0.4379
#
# Epoch 00039: val_loss did not improve from -0.52495
# Epoch 40/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2748 - dice_coef: 0.3613 - iou_coef: 0.2172 - val_loss: -0.5153 - val_dice_coef: 0.6220 - val_iou_coef: 0.4381
#
# Epoch 00040: val_loss did not improve from -0.52495
# Epoch 41/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2745 - dice_coef: 0.3620 - iou_coef: 0.2161 - val_loss: -0.5156 - val_dice_coef: 0.6222 - val_iou_coef: 0.4385
#
# Epoch 00041: val_loss did not improve from -0.52495
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 42/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2676 - dice_coef: 0.3524 - iou_coef: 0.2110 - val_loss: -0.5154 - val_dice_coef: 0.6220 - val_iou_coef: 0.4383
#
# Epoch 00042: val_loss did not improve from -0.52495
# Epoch 43/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2664 - dice_coef: 0.3531 - iou_coef: 0.2086 - val_loss: -0.5155 - val_dice_coef: 0.6221 - val_iou_coef: 0.4383
#
# Epoch 00043: val_loss did not improve from -0.52495
# Epoch 44/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2613 - dice_coef: 0.3451 - iou_coef: 0.2054 - val_loss: -0.5150 - val_dice_coef: 0.6215 - val_iou_coef: 0.4379
#
# Epoch 00044: val_loss did not improve from -0.52495
# Epoch 45/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2800 - dice_coef: 0.3693 - iou_coef: 0.2205 - val_loss: -0.5152 - val_dice_coef: 0.6217 - val_iou_coef: 0.4381
#
# Epoch 00045: val_loss did not improve from -0.52495
# Epoch 46/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2831 - dice_coef: 0.3704 - iou_coef: 0.2248 - val_loss: -0.5150 - val_dice_coef: 0.6215 - val_iou_coef: 0.4379
#
# Epoch 00046: val_loss did not improve from -0.52495
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 47/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2888 - dice_coef: 0.3835 - iou_coef: 0.2257 - val_loss: -0.5157 - val_dice_coef: 0.6223 - val_iou_coef: 0.4386
#
# Epoch 00047: val_loss did not improve from -0.52495
# Epoch 48/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2721 - dice_coef: 0.3602 - iou_coef: 0.2134 - val_loss: -0.5154 - val_dice_coef: 0.6220 - val_iou_coef: 0.4383
#
# Epoch 00048: val_loss did not improve from -0.52495
# Epoch 49/500
# 115/115 [==============================] - 104s 906ms/step - loss: -0.2718 - dice_coef: 0.3587 - iou_coef: 0.2139 - val_loss: -0.5157 - val_dice_coef: 0.6222 - val_iou_coef: 0.4386
#
# Epoch 00049: val_loss did not improve from -0.52495
# Epoch 50/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2671 - dice_coef: 0.3528 - iou_coef: 0.2101 - val_loss: -0.5157 - val_dice_coef: 0.6222 - val_iou_coef: 0.4386
#
# Epoch 00050: val_loss did not improve from -0.52495
# Epoch 51/500
# 115/115 [==============================] - 104s 905ms/step - loss: -0.2682 - dice_coef: 0.3582 - iou_coef: 0.2082 - val_loss: -0.5155 - val_dice_coef: 0.6220 - val_iou_coef: 0.4384
#
# Epoch 00051: val_loss did not improve from -0.52495
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 1e-07.

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['dice_coef'], label='Dice Coefficient')
plt.plot(history.history['val_dice_coef'], label='Validation Dice Coefficient')
plt.title('Dice Coefficient Curves')
plt.xlabel('Epoch')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.show()

# %%
plt.plot(history.history['lr'], label='Learning Rate')
plt.title('Learning Rate Schedule')
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.legend()
plt.show()

# %%
from tqdm import tqdm
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"


""" Creating a directory """

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
import pandas as pd
if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
    with CustomObjectScope({'loss': loss, 'dice_coef': dice_coef, 'iou_coef': iou_coef}):
        model = tf.keras.models.load_model(os.path.join("files", "model2.h5"))

    """ Dataset """
    dataset_path = "/home/akshatt/nandan/dataset/dataset/archive/"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    """ Prediction and Evaluation """
    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_y)):
        """ Extracting the name """
        name = x.split("/")[-1]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR) ## [H, w, 3]
        image = cv2.resize(image, (W, H))       ## [H, w, 3]
        x = image/255.0                         ## [H, w, 3]
        x = np.expand_dims(x, axis=0)           ## [1, H, w, 3]

        """ Reading the mask """
        mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (W, H))

        """ Prediction """
        y_pred = model.predict(x, verbose=0)[0]
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred >= 0.5
        y_pred = y_pred.astype(np.int32)

        """ Saving the prediction """
        save_image_path = os.path.join("results2", name)
        save_results(image, mask, y_pred, save_image_path)

        """ Flatten the array """
        mask = mask/255.0
        mask = (mask > 0.5).astype(np.int32).flatten()
        y_pred = y_pred.flatten()

        """ Calculating the metrics values """
        f1_value = f1_score(mask, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(mask, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
        precision_value = precision_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
        y_pred = y_pred.astype(np.float32)
        mask = mask.astype(np.float32).flatten()
        dice_value = dice_coef(mask, y_pred)
        SCORE.append([name, f1_value, jac_value, recall_value, precision_value, dice_value])

    """ Metrics values """
    score = [s[1:]for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"F1: {score[0]:0.5f}")
    print(f"Jaccard: {score[1]:0.5f}")
    print(f"Recall: {score[2]:0.5f}")
    print(f"Precision: {score[3]:0.5f}")
    print(f"dice_value: {score[4]:0.5f}")

    df = pd.DataFrame(SCORE, columns=["Image", "F1", "Jaccard", "Recall", "Precision", "Dice_value"])
    df.to_csv("files/score2.csv")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 612/612 [01:02<00:00,  9.87it/s]
# F1: 0.56778
# Jaccard: 0.43896
# Recall: 0.74312
# Precision: 0.52617
# dice_value: 0.56823
